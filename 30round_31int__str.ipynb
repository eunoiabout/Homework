# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/30round_31int__str.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#30반올림 수 구하기: round()

# %%
ret = round(42.195)
print(ret)
# Out:
# 42

# %%
ret = round(42.195,0)
print(ret)
# Out:
# 42.0

# %%
ret = round(42.195,1)
print(ret)
# Out:
# 42.2

# %%
ret = round(42.195,-1)
print(ret)
# Out:
# 40.0

# %%
#31수치자료형 변환: int(), float(), str()

# %%
floatData = 1234.5
intData = int(floatData)
print(f'intData{intData}자료형은{type(intData)}입니다.')
# Out:
# intData1234자료형은<class 'int'>입니다.

# %%
strData = 1234
intData = int(strData)
print(f'intData{intData}자료형은{type(intData)}입니다.')
# Out:
# intData1234자료형은<class 'int'>입니다.

# %%
strData = '1234.5'
intData = int(float(strData))
print(f'intData{intData}자료형은{type(intData)}입니다.')
# Out:
# intData1234자료형은<class 'int'>입니다.

# %%
strData = '1234.5'
floatData = float(strData)
print(f'floatData{floatData}자료형은{type(floatData)}입니다.')
# Out:
# floatData1234.5자료형은<class 'float'>입니다.

# %%
print(float('2e5'))
print(float('2e-3'))
# Out:
# 200000.0
# 0.002

# %%
intData = 1234; strData1 = str(intData)
floatData1 = 1234.5; strData2 = str(floatData1)
floatData2 = 1e-3; strData3 = str(floatData2)

print(f'정수{intData} => 문자열{strData1},{type(strData1)}')
print(f'실수{floatData1} => 문자열{strData2},{type(strData2)}')
print(f'실수{floatData2} => 문자열{strData3},{type(strData3)}')
# Out:
# 정수1234 => 문자열1234,<class 'str'>
# 실수1234.5 => 문자열1234.5,<class 'str'>
# 실수0.001 => 문자열0.001,<class 'str'>
