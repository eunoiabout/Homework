# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/52in_notin_53s_index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#52시퀀스 자료에서 요소 체크: in, not, in

# %%
lyrics = 'A lot of things occur each day! every day!!'
flag = 'things' in lyrics
print(flag)
# Out:
# True

# %%
lyrics = 'A lot of things occur each day! every day!!'
flag = 'today' not in lyrics
print(flag)
# Out:
# True

# %%
urlList = ['url1','url2','url3']
if 'url4' in urlList:
    print('url4가 urlList의 요소로 존재합니다.')
else:
    print('url4가 urlList의 요소로 존재하지 않습니다.')
# Out:
# url4가 urlList의 요소로 존재하지 않습니다.

# %%
#53시퀀스 자료의 특정 요소 인덱스 구하기: s.index()

# %%
fruits = ('사과','배','참외','수박','배','오렌지')
pos = fruits.index('배')
print(f'배는 {pos + 1}번째 과일입니다.')
# Out:
# 배는 2번째 과일입니다.

# %%
fruits = ('사과','배','참외','수박','배','오렌지')
pos = fruits.index('배',3)
print(f'배는 {pos + 1}번째 과일입니다.')
# Out:
# 배는 5번째 과일입니다.

# %%
fruits = ('사과','배','참외','수박','배','오렌지')
pos = fruits.index('사과',3)
print(f'배는 {pos + 1}번째 과일입니다.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3199203309.py in <cell line: 0>()
#       1 fruits = ('사과','배','참외','수박','배','오렌지')
# ----> 2 pos = fruits.index('사과',3)
#       3 print(f'배는 {pos + 1}번째 과일입니다.')
#
# ValueError: tuple.index(x): x not in tuple
