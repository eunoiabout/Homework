# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/22rule_calculation_23comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#22연산자 축약: +=, -=, *=, /=

# %%
#a = a + 1
#a += 1

# %%
#a -= 1
#a *= 2
#a /= 2

# %%
#23비교연산자:==,!=,<,<=,>,>=

# %%
x = 1; y = 2
strData1 = 'Hello';strData2 = 'python'
print(x == y)
print(x != y)
print(strData1 == strData2)
print(strData2 == 'python')
print(strData1 < strData2)
# Out:
# False
# True
# False
# True
# True
