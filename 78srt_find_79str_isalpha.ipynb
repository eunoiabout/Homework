# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/78srt_find_79str_isalpha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#78 문자열에서 특정 문자열 위치 찾기:str.find()

# %%
sample =  'A lot of things occur each day, it\'s very dynamical every day.'
pos = sample.find ('day')
print(pos)
# Out:
# 27

# %%
spos = 0
idx = 0
count = 1
while idx != -1:
    idx = sample.find('day', spos)
    print(f'"day"가 발견된 [{count}]번째 인덱스 {idx}')
    spos = idx + 1
    count += 1
# Out:
# "day"가 발견된 [1]번째 인덱스 27
# "day"가 발견된 [2]번째 인덱스 58
# "day"가 발견된 [3]번째 인덱스 -1

# %%
#79 문자열이 언어 문자로만 구성되었는지 확인:str.isalpha()

# %%
strList = ['Hello','오징어게임','파이썬 lover','안녕!','제3세계']

# %%
for text in strList:
    print(f'"{text}"\t-->{text.isalpha()}')
# Out:
# "Hello"	-->True
# "오징어게임"	-->True
# "파이썬 lover"	-->False
# "안녕!"	-->False
# "제3세계"	-->False
