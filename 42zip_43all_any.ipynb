# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/42zip_43all_any.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#42인덱스가 같은 요소끼리 짝짓기: zip()

# %%
male = ['슈퍼맨','심봉사','로미오','이몽룡','마루치']
female = ['원더우먼','뺑덕어멍','줄리엣','성춘향','아라치']
couples = zip(male,female)
for couple in couples:
    print(couple)
# Out:
# ('슈퍼맨', '원더우먼')
# ('심봉사', '뺑덕어멍')
# ('로미오', '줄리엣')
# ('이몽룡', '성춘향')
# ('마루치', '아라치')

# %%
male = ['슈퍼맨','심봉사','로미오']
female = ['원더우먼','뺑덕어멍','줄리엣','성춘향','아라치']
for couple in zip(male,female):
    print(couple)
# Out:
# ('슈퍼맨', '원더우먼')
# ('심봉사', '뺑덕어멍')
# ('로미오', '줄리엣')

# %%
male = ['슈퍼맨','심봉사','로미오']
female = ['원더우먼','뺑덕어멍','줄리엣','성춘향','아라치']
for couple in zip(male,female): # Removed strict=True
    print(couple)
# Out:
# ('슈퍼맨', '원더우먼')
# ('심봉사', '뺑덕어멍')
# ('로미오', '줄리엣')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3961876706.py in <cell line: 0>()
#       1 male = ['슈퍼맨','심봉사','로미오']
#       2 female = ['원더우먼','뺑덕어멍','줄리엣','성춘향','아라치']
# ----> 3 for couple in zip(male,female, strict = True):
#       4     print(couple)
#
# ValueError: zip() argument 2 is longer than argument 1

# %%
#43모든 요소가 참인지 확인하기: all(), any()

# %%
listData = [0,1,2,3,4]
print(all(listData))
print(any(listData))
# Out:
# False
# True

# %%
tupleData = (0,False,'',[],(),{},None)
print(all(tupleData))
print(any(tupleData))
# Out:
# False
# False
