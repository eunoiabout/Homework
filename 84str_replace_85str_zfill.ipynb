# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/84str_replace_85str_zfill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#84 문자열에서 특정 문자열을 다른 문자열로 바꾸기: str.replace()

# %%
text = '문자열: 파이썬에서 시퀀스 자료 중 하나임'
ret = text.replace('문자열', '텍스트')
print(ret)
# Out:
# 텍스트: 파이썬에서 시퀀스 자료 중 하나임

# %%
text = '매일 많은 일들이 일어납니다.'
ret = text.replace('일', '사건')
print(ret)
# Out:
# 매사건 많은 사건들이 사건어납니다.

# %%
#85 문자열의 왼쪽을 0으로 채우기:str.zfill()

# %%
numData = ['5','27','342','1004']
for numstr in numData:
    ret = numstr.zfill(4)
    print(ret)
# Out:
# 0005
# 0027
# 0342
# 1004

# %%
numData = ['-5','-27','-342','-1004']
for numstr in numData:
    ret = numstr.zfill(4)
    print(ret)
# Out:
# -005
# -027
# -342
# -1004
