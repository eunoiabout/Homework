# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/44sorted_45sequence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#44요소 정렬: sorted()

# %%
listData = [42,1,39,27,44,8]
ret1 = sorted(listData)
ret2 = sorted(listData, reverse = True)
print(ret1)
print(ret2)
print(listData)
# Out:
# [1, 8, 27, 39, 42, 44]
# [44, 42, 39, 27, 8, 1]
# [42, 1, 39, 27, 44, 8]

# %%
tupleData = ('사과','배','오렌지','수박','참외',)
ret = sorted(tupleData)
print(ret)
# Out:
# ['배', '사과', '수박', '오렌지', '참외']

# %%
strData = 'I love you!'
ret = sorted(strData)
print(ret)
# Out:
# [' ', ' ', '!', 'I', 'e', 'l', 'o', 'o', 'u', 'v', 'y']

# %%
population = {'김씨':2834,'이씨':2288,'박씨':1889}
ret = sorted(population)
print(ret)
# Out:
# ['김씨', '박씨', '이씨']

# %%
#45시퀀스 자료형 종류 및 특성

# %%
listData = [1,2,3,4,5]

# %%
tupleData = (1,2,3,4,5)

# %%
strData1 = '010-1234-5678'
strData2 = '사랑해요 파이썬!'
strData3 = 'I love you python!'

# %%
bstr = b'Helllo python!'
