# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/34repeatable_35iterator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#34반복 가능 이해하기

# %%
iterableData1 = [1,2,3,4,5]
iterableData2 = ('a','b','c')
iterableData3 = 'I love you!'
iterableData6 = range(10)
iterableData4 = {97:'a',98:'b'}
iterableData5 = {'사과','배','오렌지'}

# %%
#35이터레이터(iterator),iter(),neext() 이해하기

# %%
listData = [1,2,3,4]
iterator1 = listData.__iter__()
print(type(iterator1))
# Out:
# <class 'list_iterator'>

# %%
listData = [1,2,3,4]
iterator2 = iter(listData)
print(type(iterator2))
# Out:
# <class 'list_iterator'>
