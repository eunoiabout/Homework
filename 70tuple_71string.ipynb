# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/70tuple_71string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#70 튜플 이헤하기 (tuple)

# %%
tupleData = 1,'two','셋'
print(tupleData)
# Out:
# (1, 'two', '셋')

# %%
tupleData = (1,'two','셋')
print(tupleData)
# Out:
# (1, 'two', '셋')

# %%
x,y,z, = tupleData
print(f'x={x},y={y},z={z}')
# Out:
# x=1,y=two,z=셋

# %%
tupleData = (0,1,2,3,4)
tupleData[3] = 'Three'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3668647258.py in <cell line: 0>()
#       1 tupleData = (0,1,2,3,4)
# ----> 2 tupleData[3] = 'Three'
#
# TypeError: 'tuple' object does not support item assignment

# %%
#71 문자열(string) 객체

# %%
strData1 = '안녕하세요'
strData2 = '작은따옴표 "큰따옴표"를 포함하는 문자열이 가능합니다.'
print(strData1)
print(strData2)
# Out:
# 안녕하세요
# 작은따옴표 "큰따옴표"를 포함하는 문자열이 가능합니다.

# %%
strData3 = "안녕하세요"
strData4 = "큰따옴표는 '작은따옴표'를 포함하는 문자열이 가능합니다."
print(strData3)
print(strData4)
# Out:
# 안녕하세요
# 큰따옴표는 '작은따옴표'를 포함하는 문자열이 가능합니다.

# %%
strData5 = '''3중 작은따옴표는
        여러 줄에 걸친 문자열이 가능합니다.'''
print(strData5)
# Out:
# 3중 작은따옴표는
#         여러 줄에 걸친 문자열이 가능합니다.

# %%
strData6 = """3중 큰따옴표역시
여러 줄에 걸친 문자열이 가능합니다"""
print(strData6 )
# Out:
# 3중 큰따옴표역시
# 여러 줄에 걸친 문자열이 가능합니다
