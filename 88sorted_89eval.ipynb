# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/88sorted_89eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#88 문자열 정렬하기: sorted()

# %%
randstr = 'nk315nnkakkavnzrit'
ret = sorted(randstr)
print(ret)
# Out:
# ['1', '3', '5', 'a', 'a', 'i', 'k', 'k', 'k', 'k', 'n', 'n', 'n', 'n', 'r', 't', 'v', 'z']

# %%
final = ''.join(ret)
print(final)
# Out:
# 135aaikkkknnnnrtvz

# %%
#89문자열로 된 식 실행하기: eval()

# %%
expression = '123 + 456'
answer = eval(expression)
print(f'{expression} = {answer}')
# Out:
# 123 + 456 = 579

# %%
expression = 'round(3.14)'
print(f'{expression} = {eval(expression)}')
# Out:
# round(3.14) = 3

# %%
ret = eval('안녕하세요')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4215630329.py in <cell line: 0>()
# ----> 1 ret = eval('안녕하세요')
#
# <string> in <module>
#
# NameError: name '안녕하세요' is not defined
