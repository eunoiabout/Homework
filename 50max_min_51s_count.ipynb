# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/50max_min_51s_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#50시퀀스 자료에서 최대/최소 요소 구하기: max(), min()

# %%
listData = [9.96, 1.38, 5.45, 6.78, 4.67, 7.78, 4.67, 9.34]
print(max(listData))
print(min(listData))
# Out:
# 9.96
# 1.38

# %%
strData = 'AlotofThingsOccurEachday'
print(max(strData))
print(min(strData))
# Out:
# y
# A

# %%
strList = ['jang','apple12','3sung','sam']
print(max(strList))
print(min(strList))
# Out:
# sam
# 3sung

# %%
list1 = [1,2,3,'a','b','c']
print(max(list1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2750716916.py in <cell line: 0>()
#       1 list1 = [1,2,3,'a','b','c']
# ----> 2 print(max(list1))
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
#51시퀀스 자료에서 특정 요소 개수: s.count()

# %%
lyrics = 'A lot of things occur each day! every day!!'
print(lyrics.count('o'))
# Out:
# 3

# %%
lyrics = 'A lot of things occur each day! every day!!'
print(lyrics.count('day'))
# Out:
# 2

# %%
lyrics = 'A lot of things occur each day! every day!!'
print(lyrics.count(' '))
# Out:
# 8

# %%
listData = [1,6,1,4,8,4,12,1,0,9,9,7,4,3,6,7,3,2,]
print(listData.count(1))
# Out:
# 3
