# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/10type_annotation_11input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#10_타입 어노테이션(Type Annotation)

# %%
name = '권소연'
age = 20
weight = 49
is_badman = False

# %%
name: str = '권소연'
age: int = 20
weight: float = 49
is_badman: bool = False

# %%
booklist:list[str] = ['권소연','이재윤','윤기연']

# %%
island: tuple[str,float,float] = ('독도',131.52,37.14)

# %%
top4_familyname:dict[str,int]={'권씨':123456, '전씨':345677, '서씨':963721,'전씨':893768}

# %%
fruits: set[str] = {'사과','배','수박','참외','딸기'}

# %%
print(_annotations_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2452480257.py in <cell line: 0>()
# ----> 1 print(_annotations_)
#
# NameError: name '_annotations_' is not defined

# %%
fruits: set[str] = {'사과','배','수박','참외','딸기'}
fruits = {1,2,3,4,5}
print(fruits)
# Out:
# {1, 2, 3, 4, 5}

# %%
#11_사용자 입력: input()

# %%
userInput = input()
print('사용자가 입력한 값은 <'+ userInput + '>입니다.')
# Out:
# 10
# 사용자가 입력한 값은 <10>입니다.

# %%
userInput = input('값을 입력하세요:')
print('사용자가 입력한 값은 <'+ userInput + '>입니다.')
# Out:
# 값을 입력하세요:yes
# 사용자가 입력한 값은 <yes>입니다.
