# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/26int_float_27complex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#26정수, 실수: int, float

# %%
intData1 = 5
intData2 = 10
ret = intData2 / intData1
print(type(ret))
# Out:
# <class 'float'>

# %%
numData = 2e2
print(type(numData))
# Out:
# <class 'float'>

# %%
#27복소수: complex

# %%
cData1 = 1 + 1j
cData2 = complex(1,1)
print(cData1 == cData2)
# Out:
# True

# %%
print(cData1.real)
print(cData2.imag)
# Out:
# 1.0
# 1.0

# %%
complexData1 = 1 - 5j
complexData2 = complex(2,3)
print(complexData1.conjugate())
print(complexData2.conjugate())
# Out:
# (1+5j)
# (2-3j)
