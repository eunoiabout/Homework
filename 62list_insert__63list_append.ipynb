# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/62list_insert__63list_append.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#62리스트에 삽입하기: list.insert()

# %%
outer_planets = ['목성','천왕성','해왕성']
pos = outer_planets.index('천왕성')
outer_planets.insert(pos,'토성')
print(outer_planets)
# Out:
# ['목성', '토성', '천왕성', '해왕성']

# %%
outer_planets.insert(-1, '명왕성')
print(outer_planets)
# Out:
# ['목성', '토성', '천왕성', '명왕성', '해왕성']

# %%
outer_planets = ['목성','토성','천왕성','해왕성']
outer_planets.insert(len(outer_planets),'명왕성')
print(outer_planets)
# Out:
# ['목성', '토성', '천왕성', '해왕성', '명왕성']

# %%
#63리스트 맨 마지막에 요소 추가하기: list.append()

# %%
fileList = []
for i in range(3):
    fname = input(f'파일 이름을 입력하세요:[{i+1}/3]:')
    if fname not in fileList:
      fileList.append(fname)
    print(f'현재 저장된 파일들:{fileList}')
# Out:
# 파일 이름을 입력하세요:[1/3]:a.jpg
# 현재 저장된 파일들:['a.jpg ']
# 파일 이름을 입력하세요:[2/3]:b.jpg
# 현재 저장된 파일들:['a.jpg ', 'b.jpg']
# 파일 이름을 입력하세요:[3/3]:b.jpg
# 현재 저장된 파일들:['a.jpg ', 'b.jpg']
