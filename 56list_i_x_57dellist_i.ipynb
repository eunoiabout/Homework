# %% [markdown]
# <a href="https://colab.research.google.com/github/eunoiabout/Homework/blob/main/56list_i_x_57dellist_i.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#56리스트의 요소값 변경: list[i] = x

# %%
solarsys = ['태양','수성','금성','지구','화성','목성','토성','천왕성','해왕성']
solarsys[3] = 'earth'
print(solarsys)
# Out:
# ['태양', '수성', '금성', 'earth', '화성', '목성', '토성', '천왕성', '해왕성']

# %%
solarsys_ko = ['태양','수성','금성','지구','화성','목성','토성','천왕성','해왕성']
solarsys_en = ['Sun','Mercury','Venus','Earth','Mars','Jupiter','Saturn','Uranus','Naptune']

for i in range(len(solarsys_ko)):
    solarsys_ko[i] = solarsys_en[i]

print(solarsys_ko)
# Out:
# ['Sun', 'Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Naptune']

# %%
#57리스트에서 요소 삭제하기: del list[i]

# %%
fruits = ['사과','배','오렌지','수박','참외']
del fruits[1]
print(fruits)
del fruits[-1]
print(fruits)
# Out:
# ['사과', '오렌지', '수박', '참외']
# ['사과', '오렌지', '수박']

# %%
 solarsys = ['태양','수성','금성','지구','화성','소행성대','목성','토성']
del solarsys[4:6]
print(solarsys)
# Out:
# ['태양', '수성', '금성', '지구', '목성', '토성']

# %%
del solarsys[:]
print(solarsys)
# Out:
# []

# %%
solarsys = ['태양','수성','금성','지구','화성','소행성대','목성','토성']
if '소행성대' in solarsys:
    idx = solarsys.index('소행성대')
    del solarsys[idx]

print(solarsys)
# Out:
# ['태양', '수성', '금성', '지구', '화성', '목성', '토성']

# %%
fruits = ['사과','배','오렌지','수박','참외']
del fruits
print(fruits)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3265053029.py in <cell line: 0>()
#       1 fruits = ['사과','배','오렌지','수박','참외']
#       2 del fruits
# ----> 3 print(fruits)
#
# NameError: name 'fruits' is not defined
